# %% [markdown]
# $(((P \land Q) \lor R) \implies (R \lor S))$ is False
# that means
# `lhs is True` and `rhs is False`
#
# rhs = $R \lor S \implies False$ then both should be False.
# lhs = $((P \land Q) \lor False)$ should be True meaning $R \land Q$ should be True.
#
# P = True,
# Q = True,
# R = False,
# S = False

# %% [markdown]
# $
# (R \implies S) \iff (P \land Q)
# $ is True and P is False

# %% [markdown]
# rhs is False $\implies$ lhs is False
# $R \implies S$ is False
# which can be when lhs is True and rhs is False
# which gives R = True, S = False, P = True, Q = True or False

# %% [markdown]
# $
# \forall x \in X, P(x)
# $
# $
# \exists y \in Y, P(y)
# $

# %% [markdown]
# $
# \forall x \in \mathbb{Z}, 2n \text{ is even}
# $

# %% [markdown]
# $$
# \forall x \in \mathbb{Z} \text{ is even}
# $$

# %% [markdown]
# Every even integer greater than 2 is the sum of two primes.
#
# $
# \forall n \in \mathbb{Z}, n>2 \implies {\exists p,q \in \mathbb{P}, p+q=n}
# $
